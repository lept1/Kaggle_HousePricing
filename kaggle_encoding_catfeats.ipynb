# %% [markdown]
# # **KAGGLE**

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from IPython.display import IFrame

IFrame(src='https://en.wikipedia.org/wiki/house', width=700, height=500)
# Out:
#         <iframe
#             width="700"
#             height="500"
#             src="https://en.wikipedia.org/wiki/house"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Load the train data

# %% [markdown]
# Firstly, we must load the dataset. We use [Pandas](https://pandas.pydata.org/) . I load the dataset and convert the categorical non numeric features into numeric ones.

# %%
data = pd.read_csv("X_train.csv", encoding="utf8",converters={'product_type': lambda x: int(x == 'Investment'),'thermal_power_plant_raion': lambda x: int(x == 'yes')
                                                                  ,'culture_objects_top_25': lambda x: int(x == 'yes'),'incineration_raion': lambda x: int(x == 'yes'),
                                                                  'oil_chemistry_raion': lambda x: int(x == 'yes'),'radiation_raion': lambda x: int(x == 'yes')
                                                                  ,'railroad_terminal_raion': lambda x: int(x == 'yes'),'big_market_raion': lambda x: int(x == 'yes')
                                                                  ,'nuclear_reactor_raion': lambda x: int(x == 'yes'),'detention_facility_raion': lambda x: int(x == 'yes')
                                                                  ,'water_1line': lambda x: int(x == 'yes'),'big_road1_1line': lambda x: int(x == 'yes')
                                                                  ,'railroad_1line': lambda x: int(x == 'yes')})

# %%
data = pd.get_dummies(data, columns=["ecology"])

# %%
macro=pd.read_csv("macro.csv", encoding="utf8")

# %%
train_data=pd.merge_ordered(data, macro, on='timestamp', how='left')

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(train_data.dtypes)
# Out:
# id                                              int64
# timestamp                                      object
# full_sq                                         int64
# life_sq                                       float64
# floor                                         float64
# max_floor                                     float64
# material                                      float64
# build_year                                    float64
# num_room                                      float64
# kitch_sq                                      float64
# state                                         float64
# product_type                                    int64
# sub_area                                       object
# area_m                                        float64
# raion_popul                                     int64
# green_zone_part                               float64
# indust_part                                   float64
# ...

# %%
train_data=train_data.select_dtypes(exclude=['object'])

# %% [markdown]
# how much houses?

# %%
train_data.id.unique().shape
# Out:
# (21329,)

# %% [markdown]
# how much features?

# %%
train_data.columns.shape
# Out:
# (390,)

# %% [markdown]
# Print data description

# %%
f = open("data_description.txt", "r")
print(f.read())
# Out:
# price_doc: sale price (this is the target variable)
# id: transaction id
# timestamp: date of transaction
# full_sq: total area in square meters, including loggias, balconies and other non-residential areas
# life_sq: living area in square meters, excluding loggias, balconies and other non-residential areas
# floor: for apartments, floor of the building
# max_floor: number of floors in the building
# material: wall material
# build_year: year built
# num_room: number of living rooms
# kitch_sq: kitchen area
# state: apartment condition
# product_type: owner-occupier purchase or investment
# sub_area: name of the district
#
# The dataset also includes a collection of features about each property's surrounding neighbourhood (known as a Raion). Most of the feature names are self explanatory, with the following notes. See below for a complete list.
#
# full_all: subarea population
# male_f, female_f: subarea population by gender
# young_*: population younger than working age
# ...

# %% [markdown]
# # Load the train data

# %% [markdown]
# Firstly, we must load the dataset. We use [Pandas](https://pandas.pydata.org/) . I load the dataset and convert the categorical non numeric features into numeric ones.

# %%
data = pd.read_csv("X_train.csv", encoding="utf8",converters={'product_type': lambda x: int(x == 'Investment'),'thermal_power_plant_raion': lambda x: int(x == 'yes')
                                                                  ,'culture_objects_top_25': lambda x: int(x == 'yes'),'incineration_raion': lambda x: int(x == 'yes'),
                                                                  'oil_chemistry_raion': lambda x: int(x == 'yes'),'radiation_raion': lambda x: int(x == 'yes')
                                                                  ,'railroad_terminal_raion': lambda x: int(x == 'yes'),'big_market_raion': lambda x: int(x == 'yes')
                                                                  ,'nuclear_reactor_raion': lambda x: int(x == 'yes'),'detention_facility_raion': lambda x: int(x == 'yes')
                                                                  ,'water_1line': lambda x: int(x == 'yes'),'big_road1_1line': lambda x: int(x == 'yes')
                                                                  ,'railroad_1line': lambda x: int(x == 'yes')})

# %%
data = pd.get_dummies(data, columns=["ecology"])

# %%
macro=pd.read_csv("macro.csv", encoding="utf8")

# %%
train_data=pd.merge_ordered(data, macro, on='timestamp', how='left')

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(train_data.dtypes)
# Out:
# id                                              int64
# timestamp                                      object
# full_sq                                         int64
# life_sq                                       float64
# floor                                         float64
# max_floor                                     float64
# material                                      float64
# build_year                                    float64
# num_room                                      float64
# kitch_sq                                      float64
# state                                         float64
# product_type                                    int64
# sub_area                                       object
# area_m                                        float64
# raion_popul                                     int64
# green_zone_part                               float64
# indust_part                                   float64
# ...

# %%
train_data=train_data.select_dtypes(exclude=['object'])

# %% [markdown]
# how much houses?

# %%
train_data.id.unique().shape
# Out:
# (21329,)

# %% [markdown]
# how much features?

# %%
train_data.columns.shape
# Out:
# (390,)

# %% [markdown]
# Print data description

# %%
f = open("data_description.txt", "r")
print(f.read())
# Out:
# price_doc: sale price (this is the target variable)
# id: transaction id
# timestamp: date of transaction
# full_sq: total area in square meters, including loggias, balconies and other non-residential areas
# life_sq: living area in square meters, excluding loggias, balconies and other non-residential areas
# floor: for apartments, floor of the building
# max_floor: number of floors in the building
# material: wall material
# build_year: year built
# num_room: number of living rooms
# kitch_sq: kitchen area
# state: apartment condition
# product_type: owner-occupier purchase or investment
# sub_area: name of the district
#
# The dataset also includes a collection of features about each property's surrounding neighbourhood (known as a Raion). Most of the feature names are self explanatory, with the following notes. See below for a complete list.
#
# full_all: subarea population
# male_f, female_f: subarea population by gender
# young_*: population younger than working age
# ...

# %% [markdown]
# ## Extract the target

# %%
y = train_data['price_doc']

# %%
y.head
# Out:
# <bound method NDFrame.head of 0         5850000
# 1         6000000
# 2         5700000
# 3        13100000
# 4         5500000
#            ...
# 21324     6970959
# 21325    10262010
# 21326    10544070
# 21327    12000000
# 21328     6750554
# Name: price_doc, Length: 21329, dtype: int64>

# %% [markdown]
# # Features analysis

# %% [markdown]
# how much NaN value are there?

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print (train_data.isnull().sum())
# Out:
# id                                                0
# full_sq                                           0
# life_sq                                        4496
# floor                                           116
# max_floor                                      6719
# material                                       6719
# build_year                                     9565
# num_room                                       6719
# kitch_sq                                       6719
# state                                          9500
# product_type                                      0
# area_m                                            0
# raion_popul                                       0
# green_zone_part                                   0
# indust_part                                       0
# children_preschool                                0
# preschool_quota                                4694
# preschool_education_centers_raion                 0
# ...

# %%
#Remove every feature with too much nan (over 5%)
#features_removed=train_data.columns[train_data.isnull().mean() >= 0.95]

# %%
#X=train_data[train_data.columns[train_data.isnull().mean() < 0.95]]

# %%
#X.head(10)

# %%
X=train_data.drop(columns=['price_doc','id'])

# %%
X.head(19)
# Out:
#     full_sq  life_sq  floor  max_floor  material  build_year  num_room  \
# 0        43     27.0    4.0        NaN       NaN         NaN       NaN
# 1        34     19.0    3.0        NaN       NaN         NaN       NaN
# 2        43     29.0    2.0        NaN       NaN         NaN       NaN
# 3        89     50.0    9.0        NaN       NaN         NaN       NaN
# 4        25     14.0   10.0        NaN       NaN         NaN       NaN
# 5        44     44.0    5.0        NaN       NaN         NaN       NaN
# 6        42     27.0    5.0        NaN       NaN         NaN       NaN
# 7        36     21.0    9.0        NaN       NaN         NaN       NaN
# 8        38     19.0   11.0        NaN       NaN         NaN       NaN
# 9        43     28.0    4.0        NaN       NaN         NaN       NaN
# 10       31     31.0    4.0        NaN       NaN         NaN       NaN
# 11       42     28.0    2.0        NaN       NaN         NaN       NaN
# ...

# %% [markdown]
# How many remaining features?

# %%
X.columns.shape
# Out:
# (388,)

# %% [markdown]
# With KNN algorithm I will correct the remaining NaN values

# %%
from sklearn.impute import KNNImputer,SimpleImputer
imputer = SimpleImputer()
#imputer = KNNImputer(n_neighbors=4,missing_values=np.nan)
imputer.fit(X)
X_i=imputer.transform(X)

# %%
#Remove quasi-constant features (over  95%)
#from sklearn.feature_selection import VarianceThreshold
#selector = VarianceThreshold(threshold=0.05)
#selector.fit(X_i)
#X_new=selector.transform(X_i)

# %%
#X_new.shape

# %%
#from sklearn.feature_selection import SelectKBest,mutual_info_regression
#selector = SelectKBest(mutual_info_regression, k=200)
#selector.fit(X_i, y)
#X_new=selector.transform(X_i)
#X_new.shape

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_i)
X_s=scaler.transform(X_i)

# %%
X_s
# Out:
# array([[-2.60167033e-01, -1.36116920e-01, -6.90522627e-01, ...,
#         -2.85272496e+00, -5.83380163e+00,  2.63226860e-01],
#        [-4.69013711e-01, -2.83504862e-01, -8.78646233e-01, ...,
#         -2.85272496e+00, -5.83380163e+00,  2.63226860e-01],
#        [-2.60167033e-01, -9.92699340e-02, -1.06676984e+00, ...,
#         -2.85272496e+00, -5.83380163e+00,  2.63226860e-01],
#        ...,
#        [-1.67346287e-01, -8.08464411e-02,  2.88382589e+00, ...,
#          4.79989119e-15,  1.99059160e-15,  1.80685894e+00],
#        [ 4.15003909e-02, -9.92699340e-02,  1.00258983e+00, ...,
#          4.79989119e-15,  1.99059160e-15,  1.80685894e+00],
#        [-5.13203549e-02,  0.00000000e+00,  1.00258983e+00, ...,
#          4.79989119e-15,  1.99059160e-15,  1.80685894e+00]])

# %%
#from sklearn.feature_selection import SelectFromModel
#from sklearn.linear_model import Ridge
#selector = SelectFromModel(estimator=Ridge(fit_intercept=True,normalize=True))
#selector.fit(X_s, y)
#X_new=selector.transform(X_s)
#X_new.shape
# Out:
# (21329, 121)

# %%
X_new=X_s

# %% [markdown]
# # Model Selection

# %%
from collections import OrderedDict
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import cross_val_score

from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor


models = OrderedDict([
          ('Knn', KNeighborsRegressor(weights='distance')),
          ('Logistic Regression', LogisticRegression()),
          ('Linear Regression', LinearRegression(fit_intercept=True,normalize=True)),
          ('Ridge', Ridge(fit_intercept=True,normalize=True)),
          ('Lasso', Lasso(fit_intercept=True,normalize=True)),  
          ('Tree', DecisionTreeRegressor()),
          ('Random Forest', RandomForestRegressor()),
          ('Boosting', GradientBoostingRegressor())
          ])


def training(X,y,model='Logistic Regression'):
    scorers='neg_mean_squared_error'
    cv=5
    if model=='Knn':
        n_neighbors=np.arange(1,100,10)
        knn=models[model]
        gs = GridSearchCV(knn,param_grid={"n_neighbors": n_neighbors},scoring=scorers,cv=cv,n_jobs=-3,verbose=2)
        gs.fit(X, y)
        return gs, gs.best_params_, gs.best_score_
    
    if model=='Logistic Regression':
        C  = np.logspace(-3,2,5)
        lr = models[model]
        gs = GridSearchCV(lr,param_grid={"C": C},scoring=scorers,cv=cv,n_jobs=-3,verbose=2)
        gs.fit(X, y)
        return gs, gs.best_params_, gs.best_score_
    
    if model=='Linear Regression':
        C  = np.logspace(-3,2,5)
        lr = models[model]
        lr.fit(X, y)
        return lr, lr.coef_
    
    if model=='Ridge':
        alpha  = np.logspace(0,2,5)
        lr = models[model]
        gs = GridSearchCV(lr,param_grid={"alpha": alpha},scoring=scorers,cv=cv,n_jobs=-3,verbose=2)
        gs.fit(X, y)
        return gs, gs.best_params_, gs.best_score_
    
    if model=='Lasso':
        alpha  = np.logspace(-2,5,5)
        lr = models[model]
        gs = GridSearchCV(lr,param_grid={"alpha": alpha},scoring=scorers,cv=cv,n_jobs=-3,verbose=2)
        gs.fit(X, y)
        return gs, gs.best_params_, gs.best_score_
    
    if model=='Tree':
        max_depth=[50,100,150,200]
        rt=models[model]
        gs = GridSearchCV(rt,param_grid={"max_depth": max_depth},scoring=scorers,cv=cv,n_jobs=-3,verbose=2)
        gs.fit(X, y)
        return gs, gs.best_params_, gs.best_score_
    
    if model=='Random Forest':
        max_depth=np.arange(1,100,10)
        n_estimators=np.arange(3,21,3)
        rf=models[model]
        gs = GridSearchCV(rf,param_grid={"max_depth": max_depth,"n_estimators": n_estimators},scoring=scorers,cv=cv,n_jobs=-3,verbose=2)
        gs.fit(X, y)
        return gs, gs.best_params_, gs.best_score_
    
    if model=='Boosting':
        max_depth=np.arange(1,100,10)
        n_estimators=np.arange(3,21,3)
        br=models[model]
        gs = GridSearchCV(br,param_grid={"max_depth": max_depth,"n_estimators": n_estimators},scoring=scorers,cv=cv,n_jobs=-3,verbose=2)
        gs.fit(X, y)
        return gs, gs.best_params_, gs.best_score_

# %% [markdown]
# Split data in test and train

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_new, y,random_state=42)

# %% [markdown]
# ## K nearest neighbours

# %%
mm,bp,bs=training(X_train,np.log1p(y_train),'Knn')
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  33 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-3)]: Done  50 out of  50 | elapsed:  6.0min finished

# %%
y_pred = mm.predict(X_test)
print('mse = ',mean_squared_error(np.log1p(y_test), y_pred))
print('mae = ',mean_absolute_error(np.log1p(y_test), y_pred))
# Out:
# mse =  0.2821761913775265
# mae =  0.3467259473688651

# %%
plt.plot(np.arange(1,100,10),mm.cv_results_['mean_test_score'])

# %%
best_knn=mm.best_estimator_

# %%
best_knn.fit(X_new,np.log1p(y))
# Out:
# KNeighborsRegressor(n_neighbors=21, weights='distance')

# %% [markdown]
# ## Linear Regrssion

# %%
mm,bp=training(X_train,np.log1p(y_train),'Linear Regression')

# %%
y_pred = mm.predict(X_test)
print('mse = ',mean_squared_error(np.log1p(y_test), y_pred))
print('mae = ',mean_absolute_error(np.log1p(y_test), y_pred))
# Out:
# mse =  0.46934828896948316
# mae =  0.31631359874744724

# %%
best_lin=mm

# %%
best_lin.fit(X_new,np.log1p(y))
# Out:
# LinearRegression(normalize=True)

# %% [markdown]
# ## Ridge

# %%
mm,bp,bs=training(X_train,np.log1p(y_train),'Ridge')
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  25 out of  25 | elapsed:    1.9s finished

# %%
y_pred = mm.predict(X_test)
print('mse = ',mean_squared_error(np.log1p(y_test), y_pred))
print('mae = ',mean_absolute_error(np.log1p(y_test), y_pred))
# Out:
# mse =  0.31912743525341186
# mae =  0.34862561976082707

# %%
plt.plot(mm.cv_results_['mean_test_score'])

# %%
best_rr=mm.best_estimator_

# %%
best_rr.fit(X_new,np.log1p(y))
# Out:
# Ridge(alpha=3.1622776601683795, normalize=True)

# %% [markdown]
# ## Lasso

# %%
mm,bp,bs=training(X_train,np.log1p(y_train),'Lasso')
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  25 out of  25 | elapsed:    1.1s finished

# %%
y_pred = mm.predict(X_test)
print('mse = ',mean_squared_error(np.log1p(y_test), y_pred))
print('mae = ',mean_absolute_error(np.log1p(y_test), y_pred))
# Out:
# mse =  0.36587203596937906
# mae =  0.42362844541421785

# %%
plt.plot(mm.cv_results_['mean_test_score'])

# %%
best_lax=mm.best_estimator_

# %%
best_lax.fit(X_new,np.log1p(y))
# Out:
# Lasso(alpha=0.01, normalize=True)

# %% [markdown]
# ## Tree Regressor

# %%
mm,bp,bs=training(X_train,np.log1p(y_train),'Tree')
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  20 out of  20 | elapsed:    2.7s finished

# %%
y_pred = mm.predict(X_test)
print('mse = ',mean_squared_error(np.log1p(y_test), y_pred))
print('mae = ',mean_absolute_error(np.log1p(y_test), y_pred))
# Out:
# mse =  0.515736227514891
# mae =  0.4685038099452818

# %%
plt.plot(mm.cv_results_['mean_test_score'])

# %%
best_tr=mm.best_estimator_

# %%
best_tr.fit(X_new,np.log1p(y))
# Out:
# DecisionTreeRegressor(max_depth=100)

# %% [markdown]
# ## Boosting

# %%
mm,bp,bs=training(X_train,np.log1p(y_train),'Boosting')

# %%
y_pred = mm.predict(X_test)
print('mse = ',mean_squared_error(np.log1p(y_test), y_pred))
print('mae = ',mean_absolute_error(np.log1p(y_test), y_pred))

# %%
plt.plot(mm.cv_results_['mean_test_score'])

# %%
best_boo=mm.best_estimator_

# %% [markdown]
# ## Random Forest

# %%
mm,bp,bs=training(X_train,np.log1p(y_train),'Random Forest')
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [Parallel(n_jobs=-3)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-3)]: Done  33 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-3)]: Done 154 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-3)]: Done 300 out of 300 | elapsed: 25.5min finished

# %%
y_pred = mm.predict(X_test)
print('mse = ',mean_squared_error(np.log1p(y_test), y_pred))
print('mae = ',mean_absolute_error(np.log1p(y_test), y_pred))
# Out:
# mse =  0.2229649192917658
# mae =  0.2799206770053163

# %%
plt.plot(mm.cv_results_['mean_test_score'])

# %%
best_rf=mm.best_estimator_

# %% [markdown]
# # Prepare the solution

# %%
tdata = pd.read_csv("X_test.csv", encoding="utf8",converters={'product_type': lambda x: int(x == 'Investment'),'thermal_power_plant_raion': lambda x: int(x == 'yes')
                                                                  ,'culture_objects_top_25': lambda x: int(x == 'yes'),'incineration_raion': lambda x: int(x == 'yes'),
                                                                  'oil_chemistry_raion': lambda x: int(x == 'yes'),'radiation_raion': lambda x: int(x == 'yes')
                                                                  ,'railroad_terminal_raion': lambda x: int(x == 'yes'),'big_market_raion': lambda x: int(x == 'yes')
                                                                  ,'nuclear_reactor_raion': lambda x: int(x == 'yes'),'detention_facility_raion': lambda x: int(x == 'yes')
                                                                  ,'water_1line': lambda x: int(x == 'yes'),'big_road1_1line': lambda x: int(x == 'yes')
                                                                  ,'railroad_1line': lambda x: int(x == 'yes')})

# %%
tdata = pd.get_dummies(tdata, columns=["ecology"])

# %%
test_data=pd.merge_ordered(tdata, macro, on='timestamp', how='left')

# %%
test_data=test_data.select_dtypes(exclude=['object'])

# %%
test_data.head()
# Out:
#      id  full_sq  life_sq  floor  max_floor  material  build_year  num_room  \
# 0  4116       77     77.0    4.0        NaN       NaN         NaN       NaN
# 1   244       67     46.0   14.0        NaN       NaN         NaN       NaN
# 2  5108       36     19.0   12.0        NaN       NaN         NaN       NaN
# 3  8005       31     21.0    3.0        NaN       NaN         NaN       NaN
# 4   728       74     44.0   10.0        NaN       NaN         NaN       NaN
#
#    kitch_sq  state  ...  provision_retail_space_modern_sqm  \
# 0       NaN    NaN  ...                              271.0
# 1       NaN    NaN  ...                              271.0
# 2       NaN    NaN  ...                              271.0
# 3       NaN    NaN  ...                              271.0
# 4       NaN    NaN  ...                              271.0
#
#    turnover_catering_per_cap  theaters_viewers_per_1000_cap  \
# 0                     6943.0                          565.0
# ...

# %%
#X_t = test_data.drop(columns=features_removed)
X_t=test_data.drop(columns=['id'])

# %%
X_t.shape
# Out:
# (9142, 388)

# %%
X_test_i = imputer.transform(X_t)

# %%
X_test_i.shape
# Out:
# (9142, 388)

# %%
X_test=scaler.transform(X_test_i)

# %%
#X_testf=selector.transform(X_test)

# %%
#X_testf.shape
# Out:
# (9142, 121)

# %%
y_pred = best_rf.predict(X_test)

# %%
solution = pd.DataFrame({"id":test_data.id.unique(), 'price_doc':np.expm1(y_pred)})
solution.head(900)
# Out:
#        id     price_doc
# 0    4116  8.414238e+06
# 1     244  5.294829e+06
# 2    5108  2.375497e+06
# 3    8005  5.075906e+06
# 4     728  3.235234e+06
# ..    ...           ...
# 895  2229  4.689340e+06
# 896  5360  4.713001e+06
# 897  6048  9.188959e+06
# 898  6932  5.847927e+06
# 899   212  5.253365e+06
#
# [900 rows x 2 columns]

# %%
solution.to_csv("solution_rf.csv", index=False)
